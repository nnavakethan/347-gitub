# %% [markdown]
# <a href="https://colab.research.google.com/github/nnavakethan/347-gitub/blob/main/text_similarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import string
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def preprocess_text(text):
  tokenize=word_tokenize(text)
  tokenize=[word.lower() for word in tokenize]
  lemmatizer=WordNetLemmatizer()
  tokenize=[lemmatizer.lemmatize(word) for word in tokenize]
  stop_words=set(stopwords.words('english'))
  tokenize=[word for word in tokenize if word.casefold() not in stop_words]
  return " ".join(tokenize)

# %%
review1="The film is very good"
review2="The film is bad"

# %%
a=preprocess_text(review1)
b=preprocess_text(review2)
print(a)
print(b)
# Out:
# film good
# film bad

# %%
vectorizer=TfidfVectorizer()
vectors=vectorizer.fit_transform([a,b])
print(vectors.toarray())
# Out:
# [[0.         0.57973867 0.81480247]
#  [0.81480247 0.57973867 0.        ]]

# %%
cosin_sim=cosine_similarity(vectors[0],vectors[1])[0][0]
print(round(cosin_sim,3))
# Out:
# 0.336

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/train.csv")
df.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative

# %%
# COSINE&JACCARD SIMILARITY
df.shape  #represents rows shows rows
# Out:
# (27481, 4)

# %%
df['text1_clean']=df['text'].astype(str).apply(preprocess_text)
df['text2_clean']=df['selected_text'].astype(str).apply(preprocess_text)
df.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  \
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative
#
#                                   text1_clean          text2_clean
# 0                         ` responded , going  ` responded , going
# 1               sooo sad miss san diego ! ! !             sooo sad
# 2                            bos bullying ...             bullying
# 3                     interview ! leave alone          leave alone
# 4  son * * * * , ` put release already bought        son * * * * ,

# %%
vectorizer=TfidfVectorizer()
tfidf_matrix1=vectorizer.fit_transform(df['text1_clean'])
tfidf_matrix2=vectorizer.transform(df['text2_clean'])

# %%
cosine_similarities=cosine_similarity(tfidf_matrix1,tfidf_matrix2)
df['cosine_similarity']=cosine_similarities.diagonal()
df.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  \
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative
#
#                                   text1_clean          text2_clean  \
# 0                         ` responded , going  ` responded , going
# 1               sooo sad miss san diego ! ! !             sooo sad
# 2                            bos bullying ...             bullying
# 3                     interview ! leave alone          leave alone
# 4  son * * * * , ` put release already bought        son * * * * ,
#
#    cosine_similarity
# 0           1.000000
# 1           0.535921
# 2           0.791472
# 3           0.763914
# 4           0.473126

# %%
review1="The film is very good"
words1=set(review1.split())
review2="The film is bad"
words2=set(review2.split())

# %%
review1="The film is very good"
words1=set(review1.split())

# %%
def jaccab_similarity(text1,text2):
  words1=set(text1.split())
  words2=set(text2.split())
  intersection=words1.intersection(words2)
  union=words1.union(words2)
  if len(union)==0:
    return 0
  jaccab_similarity=len(intersection)/len(union)
  return jaccab_similarity

# %%
df["jaccab_similarity"]=df.apply(lambda row:jaccab_similarity(row["text1_clean"],row["text2_clean"]),axis=1)
df.head()
# Out:
#        textID                                               text  \
# 0  cb774db0d1                I`d have responded, if I were going
# 1  549e992a42      Sooo SAD I will miss you here in San Diego!!!
# 2  088c60f138                          my boss is bullying me...
# 3  9642c003ef                     what interview! leave me alone
# 4  358bd9e861   Sons of ****, why couldn`t they put them on t...
#
#                          selected_text sentiment  \
# 0  I`d have responded, if I were going   neutral
# 1                             Sooo SAD  negative
# 2                          bullying me  negative
# 3                       leave me alone  negative
# 4                        Sons of ****,  negative
#
#                                   text1_clean          text2_clean  \
# 0                         ` responded , going  ` responded , going
# 1               sooo sad miss san diego ! ! !             sooo sad
# 2                            bos bullying ...             bullying
# 3                     interview ! leave alone          leave alone
# 4  son * * * * , ` put release already bought        son * * * * ,
#
#    cosine_similarity  jaccab_similarity
# 0           1.000000           1.000000
# 1           0.535921           0.333333
# 2           0.791472           0.333333
# 3           0.763914           0.500000
# 4           0.473126           0.375000
